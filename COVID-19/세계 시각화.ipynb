# %%
import json
import pandas as pd
import folium
print(folium.__version__)
# Out:
# 0.10.1

# %%
df = pd.read_csv('TC_M.csv')

# %%
df
# Out:
#      iso_code  total_cases_per_million
# 0         ABW                  945.994
# 1         AFG                  103.601
# 2         AGO                    1.308
# 3         AIA                  199.973
# 4         ALB                  297.449
# ..        ...                      ...
# 206       ZAF                  158.830
# 207       ZMB                   13.708
# 208       ZWE                    2.422
# 209  OWID_WRL                  511.382
# 210         0                    0.000
#
# [211 rows x 2 columns]

# %%
geo_path = 'TM.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
map = folium.Map(location=[36, 127], zoom_start=1)
map.choropleth(geo_data=geo_str, data=df,
              columns=['iso_code','total_cases_per_million'],
              key_on='properties.iso3',
              fill_color='YlGn',
              legend_name='iso_code')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df
# Out:
#      iso_code  total_cases_per_million
# 0         ABW                  945.994
# 1         AFG                  103.601
# 2         AGO                    1.308
# 3         AIA                  199.973
# 4         ALB                  297.449
# ..        ...                      ...
# 206       ZAF                  158.830
# 207       ZMB                   13.708
# 208       ZWE                    2.422
# 209  OWID_WRL                  511.382
# 210         0                    0.000
#
# [211 rows x 2 columns]
